# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaloMartin/Python-Bootcamp/blob/main/Unidad_09/Python_Bootcamp_Clase_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/GonzaloMartin/Python-Bootcamp/refs/heads/main/Assets/python_bootcamp_banner1.png" width="400">
#
# # **Python Bootcamp orientado a la Automatización**
#
# Para esta unidad nos vamos a centrar en el uso del Framework Pytest para la creación de tests automatizados en Python y demás agregados que nos ayudarán a mejorar la calidad de nuestro código y la eficiencia en la ejecución de pruebas.

# %% [markdown]
# # Unidad 9
#
# El objetivo de esta unidad es desarrollar los conceptos necesarios para que puedas crear automatizaciones web en tests automatizados estructurados, con reporting profesional, organización de proyecto y buenas prácticas. Para ello, utilizaremos Selenium como herramienta principal de automatización web, y aprenderemos a integrarla con Pytest para estructurar nuestros tests. Allure Reports será la herramienta que utilizaremos para generar reportes visuales y detallados de nuestras ejecuciones.
#
# Esta unidad comprende:
#
# * Pytest.
# * Allure Reports.
# * Pytest + Allure + Selenium.
# * Preparación del Entorno.
# * Instalación y Configuración.
# * Integración Básica Pytest + Allure.
# * Buenas Prácticas de uso.
# * Primer Test con Pytest.
# * Integrando Selenium con Pytest.
# * Fixtures.
# * Reporting con Allure.
# * Organización del Proyecto.
# * Buenas Prácticas para Automatizaciones.
# * Integración de Allure + Selenium.
#
# La clase incluye teoría y práctica sobre cada tema.

# %% [markdown]
# ***
# ## Pytest 🐍
#
# WIP
#
#
#
#
#
#
#
#
#
#
#
# .

# %% [markdown]
# ***
# ***
# ## *Challenge 1*
#
# > Usando Selenium, escribe el código necesario para abrir el navegador, navegar a una URL que se le ingrese por teclado, esperar 2 segundos y luego cerrar el navegador.

# %%
# Challenge 1
# Escribe tu respuesta aquí o en un archivo .py a parte.

# %% [markdown]
# ***
# ***
# ## *Challenge 2*
#
# > Usando Selenium, escribe el código para que puedas hacer las siguientes acciones en una página web:
# > 1. Abrir el navegador Chrome.
# > 2. Navegar a "https://www.google.com".
# > 3. Buscar un término ingresado por teclado en el campo de búsqueda.
# > 4. Presiona la tecla "ENTER" para iniciar la búsqueda.
# > 5. Esperar 3 segundos.
# > 6. Validar que la página cargó los resultados que buscaste.
# > 7. Cerrar el navegador.

# %%
# Challenge 2
# Escribe tu respuesta aquí o en un archivo .py a parte.

# %% [markdown]
# ***
# ***
# ## *Challenge 3*
#
# > Dado el sitio de pruebas ejemplo:
# > https://the-internet.herokuapp.com/login
# >
# > 1. Navegar al sitio.
# > 2. Completá el usuario y contraseña (los datos están en la misma página) (Recuerda capturar los locators inspeccionando cda elemento que necesites).
# > 3. Hacé clic en el botón "Login".
# > 4. Validá que el inicio de sesión fue exitoso verificando la presencia de un mensaje de éxito o la redirección a una página protegida.
# > 5. Cierra el navegador.
# >
# > **Nota:** No importa si el login es exitoso o no, lo importante es que el script realice las acciones correctamente.

# %%
# Challenge 3
# Escribe tu respuesta aquí o en un archivo .py a parte.

# %% [markdown]
# Increíble, pero terminamos con los temas más importantes sobre Selenium WebDriver.
#
# Ahora corten acá y váyanse a descansar un poco.
#
#
#
# Mentira.
#
# Nadie se va sin hacer los Chellenges Integradores!
#
# <img src="https://media1.tenor.com/m/ACcuFP91SnwAAAAC/hacker-meme.gif" width="600">

# %% [markdown]
# ***
# ***
#
# ## *Challenge Integrador 1*
#
# ### Swag Labs - (Dificultad: Media)
#
# <style>
# .alert-atom-info {
#   background-color: #2c313c;  /* fondo oscuro suave */
#   color: #c7cfd6ff;             /* custom */
#   border: 1px solid #3e4451;  /* gris oscuro */
#   padding: 15px;
#   border-radius: 5px;
#   font-family: 'Fira Code', Consolas, monospace;
# }
# </style>
# <div class="alert alert-atom-info">
#
# Automatizar un flujo completo de interacción web en el sitio de pruebas "Swag Labs" (https://www.saucedemo.com/).
#
# **Implementación:**
# - Abrir el sitio web.
# - Iniciar sesión con las credenciales proporcionadas (las credenciales están en la misma página).
# - Navegar por el catálogo de productos y agregar al menos dos productos al carrito de compras.
# - Ir al carrito de compras y verificar que los productos agregados estén presentes.
# - Proceder al checkout, completar la información requerida (nombre, apellido, código postal) y finalizar la compra.
# - Validar que la compra se haya completado exitosamente verificando el mensaje de confirmación exitoso.
# - Volver a la página principal.
# - Cerrar el navegador.
#
# **Requisitos Técnicos:**
#
# La automatización DEBE:
# * Usar esperas explícitas (WebDriverWait)
# * Manejar al menos:
#   * TimeoutException
#   * NoSuchElementException
# * Usar nombres de variables claros
#
# </div>

# %%
# Challenge Integrador 1
# Escribe tu código aquí.
# Dado que es un ejercicio largo, te recomiendo que lo hagas en un archivo nuevo .py

# %% [markdown]
# ***
# ***
# ## *Challenge Integrador 2*
#
# ### API Swag Labs - (Dificultad: Alta)
#
# <style>
# .alert-atom-info {
#   background-color: #2c313c;  /* fondo oscuro suave */
#   color: #c7cfd6ff;             /* custom */
#   border: 1px solid #3e4451;  /* gris oscuro */
#   padding: 15px;
#   border-radius: 5px;
#   font-family: 'Fira Code', Consolas, monospace;
# }
# </style>
# <div class="alert alert-atom-info">
#
# **Introducción:**
#
# Tomen este desafío como una evaluación. El objetivo es que apliquen todo lo aprendido en las unidades anteriores y en esta unidad para poder automatizar un flujo completo de interacción web junto con la integración de una API RESTful.
# El texto será un poco largo, pero si siguen los pasos al pie, no tendrán problemas en completarlo.
#
# **Sistemas Bajo Prueba:**
# * FrontEnd:
#    * Swag Labs - https://www.saucedemo.com/
#
# * BackEnd:
#    * API Swag Labs - https://dummyjson.com/products
#
# **Implementación:**
#
# El usuario se deberá loguear en el sitio web de Swag Labs utilizando las credenciales proporcionadas en la misma página. Deberá interactuar con los productos disponibles en el catálogo, validando dicha información contra la API RESTful proporcionada.
#
# 1. Automatizar el inicio de sesión en el sitio web de Swag Labs.
# 2. Validar que el usuario haya iniciado sesión correctamente.
# 3. Automatizar la API RESTful para obtener la lista de productos disponibles. (Usar requests).
# 4. Validar que se reciba una respuesta exitosa (código 200) de la API.
# 5. Obtener al menos:
#    * Nombre de un producto.
#    * Precio.
# 6. Validación Cruzada (API -> Front)
#    * Validar que el nombre y precio del producto obtenido desde la API exista en el catálogo de productos del sitio web de Swag Labs. Deben coincidir exactamente.
#    * **Si el Producto Existe:**
#       * Agregarlo al carrito de compras.
#       * Navegar al carrito y validar que el producto esté presente.
#       * Proceder al checkout, completar la información requerida (nombre, apellido, código postal) y finalizar la compra.
#       * Hacer click en "Back to Home" para volver al inicio del sitio.
#    * **Si el Producto NO Existe:**
#       * Imprimir un mensaje de error en consola y pasar al punto 7.
# 7. Hacer click en las 3 líneas de menú (hamburguesa) en la esquina superior izquierda.
# 8. Seleccionar la opción "Logout" para cerrar sesión.
# 9. Cerrar el navegador.
#
# **Usos Obligatorios:**
# * Selenium WebDriver.
# * Requests (para consumir la API RESTful).
# * Esperas explícitas (WebDriverWait).
# * No usar Sleep().
# * Manejo de excepciones:
#   * TimeoutException
#   * NoSuchElementException
#   * HTTPError (para manejar errores de la API)
# </div>
#
# No se evalúa que llegues al final. Se evalúa cómo manejás los errores cuando las cosas no salen como esperabas.
#
# Si este Challenge te resulta incómodo, no te preocupes, vas por el camino correcto 💪💪.

# %%
# Challenge Integrador 2
# Escribe tu código aquí.
# Dado que es un ejercicio largo, te recomiendo que lo hagas en un archivo nuevo .py
