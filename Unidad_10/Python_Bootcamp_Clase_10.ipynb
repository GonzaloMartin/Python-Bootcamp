# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaloMartin/Python-Bootcamp/blob/main/Unidad_10/Python_Bootcamp_Clase_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/GonzaloMartin/Python-Bootcamp/refs/heads/main/Assets/python_bootcamp_banner1.png" width="400">
#
# # **Python Bootcamp orientado a la Automatización**
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.

# %% [markdown]
# # Unidad 10
#
# En esta unidad explicaremos detalladamente el frameowrk de automatización que les ayudará a partir de ahora en su día a día.
#
# Esta unidad busca:
#
# * Entender un framework existente
# * Utilizarlo correctamente
# * Respetar su estructura
# * Extenderlo sin romperlo
# * Ejecutar pruebas web y API de forma integrada
#
# El proyecto automatiza el sitio público Automation Exercise, utilizando un enfoque profesional.
# Comenzamos.

# %% [markdown]
# ## Proyecto: Framework de Automatización con Python
#
# Les dejo a disposición un framework de automatización pensado para desarrollar proyectos de automation integrales.
# Lo desarrollé y con esto hice la automatización de la web Automation Exercice, un frontend para probar automatizaciones.  Tiene front y back, por lo que también es apto para APIs.
#
# No les voy a dejar el proyecto limpio, sino que les daré un caso ya aplicado. Ustedes lo verán y de ahí les puede servir para otros proyectos.
#
# Pueden ver el repositorio público y su documentación haciendo [click aquí.](https://github.com/GonzaloMartin/auto-automationexercise)
#
# Pueden descargar el mismo clonando el repositorio desde:
#
# ```bash
# git clone git clone https://github.com/GonzaloMartin/auto-automationexercise.git
# ```
#
# > Requisito: Tengan instalado git para poder clonar el proyecto.
#
# ### Estructura General del Proyecto
#
# Este framework sigue la estructura recomendada en la unidad 9:
#
# ```bash
# auto-automationexercise-main/
# ├── conftest.py
# ├── pytest.ini
# ├── requirements.txt
# ├── lib/
# │   └── funciones_varias.py
# ├── src/
# │   ├── apis/
# │   │   ├── auto_buscar_productos.py
# │   │   └── auto_productos.py
# │   └── pages/
# │       ├── po_01_login_logout.py
# │       ├── po_02_productos.py
# │       ├── po_03_carrito.py
# │       └── po_04_pagar.py
# └── test/
#     ├── 00_api_test.py
#     ├── 01_login_logout_test.py
#     ├── 02_comprar_producto_test.py
# ```
#
# Estructura General del Proyecto
#
# ### Principio base del framework
#
# > El test no sabe cómo se interactúa con la aplicación.
# >
# > El test solo sabe qué validar.
# >
# > Toda la lógica técnica vive fuera del test.
#
# ### Configuración del Framework
#
# #### requirements.txt
#
# Define todas las dependencias necesarias para ejecutar el framework:
# - pytest
# - selenium
# - requests
# - allure (según entorno)
#
# Esto permite:
# - reproducibilidad
# - ejecución local
# - ejecución en CI
#
# #### pytest.ini
#
# Archivo de configuración central de Pytest.
# Aquí se definen:
# - marcadores (smoke, regression, etc.)
# - comportamiento del runner
# - opciones por defecto
# Este archivo se debe modificar para definir marcadores.
#
# #### conftest.py
#
# Este archivo es el corazón del framework.
# Aquí se centraliza:
# - creación y cierre del WebDriver
# - fixtures globales
# - configuración compartida
# - comportamiento común para todos los tests
#
# Regla clave:
#
# Ningún test crea el driver por su cuenta.
#
# Esto garantiza:
# - consistencia
# - limpieza
# - control del ciclo de vida del navegador

# %% [markdown]
# ### Carpeta lib/ – Funciones auxiliares
#
# #### lib/funciones_varias.py
#
# Contiene funciones reutilizables que:
# - no pertenecen a una página
# - no son tests
# - resuelven necesidades transversales
#
# Ejemplos típicos:
# - helpers
# - utilidades
# - funciones genéricas
# > Esta carpeta evita duplicación de lógica en tests y pages.

# %% [markdown]
# ## Automatización de APIs – src/apis/ 🌐
#
# Esta carpeta encapsula toda la automatización REST.
#
# ### auto_productos.py
#
# Define funciones que:
# - consumen endpoints
# - manejan requests
# - retornan datos procesables
#
# Acá vive:
# - la lógica HTTP
# - el manejo de respuestas
# - la abstracción de la API
#
# ### auto_buscar_productos.py
#
# Especializa búsquedas o flujos concretos sobre la API:
#
# - filtrado de productos
# - validaciones específicas
# - reutilización de respuestas
#
# > El test no usa requests directamente.
# > Usa funciones del framework.

# %% [markdown]
# ## Automatización Web – src/pages/ 🖥️
#
# Implementa el Page Object Model (POM) de forma explícita.
#
# Cada archivo representa una página o flujo del sitio.
#
# ### po_01_login_logout.py
#
# Responsable de:
# - login
# - logout
# - acciones relacionadas con autenticación
#
# El test no conoce:
# - IDs
# - XPaths
# - cómo se hace click
#
# Solo invoca métodos del Page Object.
#
# ### po_02_productos.py
#
# Encapsula:
# - listado de productos
# - selección
# - navegación interna
#
# ### po_03_carrito.py
#
# Responsable de:
# - agregar productos
# - validar carrito
# - navegación al checkout
#
# ### po_04_pagar.py
#
# Modela el flujo de pago:
# - completar datos
# - avanzar pasos
# - finalizar proceso
#
# Ventaja clave:
# Si cambia la UI, se corrige un solo archivo, no todos los tests.

# %% [markdown]
# ## Carpeta test/ – Casos de Prueba 🧪
#
# Acá viven exclusivamente los tests.
#
# ### 00_api_test.py
#
# Tests de backend puro.
# - Consume funciones de src/apis
# - Valida status, respuestas y datos
# - No interactúa con UI
#
# > Demuestra que el framework soporta API testing real.
#
# ### 01_login_logout_test.py
#
# Test funcional de UI:
# - login
# - logout
# - validaciones de navegación
#
# Utiliza:
# - fixtures
# - Page Objects
# - asserts claros
#
# ### 02_comprar_producto_test.py
#
# Test end-to-end:
# - login
# - selección de producto
# - carrito
# - pago
#
# Este test demuestra:
# - uso completo del framework
# - interacción entre capas
# - flujo real de usuario
#
# ## Forma de Testear con el Framework 🔄
#
# Regla de oro
#
# > No usar Selenium crudo en tests
# >
# > No usar requests directos en tests
# >
# > Usar siempre las abstracciones del framework
#
# ### Flujo típico de un test
#
# 1. El test invoca un Page Object o API client
# 2. El framework ejecuta la lógica
# 3. El test valida el resultado
#
# Esto permite:
# - tests cortos
# - alta legibilidad
# - fácil mantenimiento

# %% [markdown]
# ## Preparado para CI / Pipelines 🚀
#
# Este framework está diseñado para:
# - ejecución local
# - ejecución automática en CI
#
# Gracias a:
# - requirements.txt
# - pytest.ini
# - estructura clara
# - fixtures centralizados
#
# El mismo comando que corre local:
# ```bash
#     pytest -v
# ```
# Puede correr bajo integración continua sin cambios de código.

# %% [markdown]
# ***
# ***
# Y eso es todo amig@s!
#
# Este tramo fue bastante largo, pero sólo es el comienzo. Faltan mucho más por hacer y esta parte ya depende de ustedes! :)
#
# Obviamte hay un Proyecto Final que los está esperando. Y es tan simple como lo que vimos!
#
# <img src="https://i.imgur.com/BuQJDsk.gif" width="600">

# %% [markdown]
# ***
# ***
#
# ## *Proyecto Final*
#
# ### Automatización Completa.
#
# <style>
# .alert-atom-info {
#   background-color: #2c313c;  /* fondo oscuro suave */
#   color: #c7cfd6ff;             /* custom */
#   border: 1px solid #3e4451;  /* gris oscuro */
#   padding: 15px;
#   border-radius: 5px;
#   font-family: 'Fira Code', Consolas, monospace;
# }
# </style>
# <div class="alert alert-atom-info">
#
# El desafío es simple. Deben automatizar, en base al framework explicado como guía, una API o un frontend de su elección, siguiendo con todas las buenas prácticas empleadas anteriormente.
# </div>
