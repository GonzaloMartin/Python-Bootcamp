# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaloMartin/Python-Bootcamp/blob/main/Unidad_10/Python_Bootcamp_Clase_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/GonzaloMartin/Python-Bootcamp/refs/heads/main/Assets/python_bootcamp_banner1.png" width="400">
#
# # **Python Bootcamp orientado a la Automatización**
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.

# %% [markdown]
# # Unidad 10
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#
# Esta unidad comprende:
#
# * Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# * Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# * Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
#
# La clase incluye teoría y práctica sobre cada tema.

# %% [markdown]
# ***
# ## WIP
#
# WIP

# %% [markdown]
# ***
# ***
# ## *Challenge 1*
#
# > Crear un test automatizado que valide una condición simple.
# >
# > Pasos:
# > - Crear un archivo test_basico.py
# > - Escribir un test que valide que 2 + 2 sea igual a 4
# > - Ejecutar el test con Pytest
# >
# > Requisitos:
# > - Usar Pytest
# > - Usar al menos un assert.

# %%
# Challenge 1
# Escribe tu respuesta aquí o en un archivo .py a parte.

# %% [markdown]
# ***
# ***
# ## *Challenge 2*
#
# > Crear un test que:
# > - Abra el siguiente link: https://www.saucedemo.com/
# > - Valide que el título de la página contenga el texto “Swag Labs”
# >
# > Requisitos:
# > - Usar fixture driver
# > - Usar Pytest
# > - Usar un assert claro
# > - No es necesario loguearse.

# %%
# Challenge 2
# Escribe tu respuesta aquí o en un archivo .py a parte.

# %% [markdown]
# ***
# ***
# ## *Challenge 3*
#
# > Generar un reporte Allure a partir de un test simple.
# > A partir del challenge anterior:
# > - Ejecutar el test generando resultados Allure
# > - Visualizar el reporte HTML
# >
# > Ejecutar:
# > ```bash
# >   pytest --alluredir=allure-results
# >   allure generate allure-results -o allure-report --clean
# > ```
# > El reporte debe mostrar:
# > - Nombre del Test
# > - Estado (pass/fail)
# > - No es obligatorio agregar steps ni screenshots.

# %%
# Challenge 3
# Escribe tu respuesta aquí o en un archivo .py a parte.

# %% [markdown]
# Listo hasta acá llegamos.
#
# Se que esta unidad fue densa, pero es fundamental para avanzar en automatización profesional.
#
# Pero tranqui, se que estaban esperando... los challenges integradores 😁😁😁.
#
# <img src="https://c.tenor.com/Wl-KdhG1N24AAAAd/tenor.gif">

# %% [markdown]
# ***
# ***
#
# ## *Challenge Integrador 1*
#
# ### Swag Labs Turbo - (Dificultad: Media)
#
# <style>
# .alert-atom-info {
#   background-color: #2c313c;  /* fondo oscuro suave */
#   color: #c7cfd6ff;             /* custom */
#   border: 1px solid #3e4451;  /* gris oscuro */
#   padding: 15px;
#   border-radius: 5px;
#   font-family: 'Fira Code', Consolas, monospace;
# }
# </style>
# <div class="alert alert-atom-info">
#
# Crear un test automatizado completo con Pytest, Selenium, Allure, Fixtures y Markers.
#
# **Consigna:**
#
# - Abrir SauceDemo (https://www.saucedemo.com/)
# - Realizar un login con credenciales válidas
# - Validar que el usuario accede a la página Products.
# - Tomar un screenshot al finalizar el test.
#
# **Requisitos:**
#
# - Usar @pytest.mark.nombre_del_marcador  (elegir el nombre que ustedes gusten)
# - Usar al menos 2 steps de Allure
# - Usar fixture driver
# - Usar espera explícita
# - Generar reporte Allure HTML.
#
# **Ayudín:**
#
# Para que Chrome no moleste con avisos de contraseñas al usar las credenciales de SauceDemo, podés abrir el navegador en modo incógnito. Agregá esto al comienzo de tu script:
#
# ```python
#   from selenium import webdriver
#   from selenium.webdriver.common.by import By
#   from selenium.webdriver.chrome.options import Options
#   options = Options()
#   options.add_argument("--incognito")
#   driver = webdriver.Chrome(options=options)
#   driver.get("https://www.saucedemo.com/")
# ```
# Esto es solo para evitar interferencias del navegador y aplica únicamente a este ejercicio.
# </div>

# %%
# Challenge Integrador 1
# Escribe tu código aquí.
# Dado que es un ejercicio largo, te recomiendo que lo hagas en un archivo nuevo .py

# %% [markdown]
# ***
# ***
# ## *Challenge Integrador 2*
#
# ### Automation Exercise Store - (Dificultad: Alta)
#
# <style>
# .alert-atom-info {
#   background-color: #2c313c;  /* fondo oscuro suave */
#   color: #c7cfd6ff;             /* custom */
#   border: 1px solid #3e4451;  /* gris oscuro */
#   padding: 15px;
#   border-radius: 5px;
#   font-family: 'Fira Code', Consolas, monospace;
# }
# </style>
# <div class="alert alert-atom-info">
#
# **Contexto:**
#
# Construir un test automatizado profesional que valide un flujo real de e-commerce utilizando Pytest como framework de testing, Selenium WebDriver, Fixtures, Markers y Reportería de Allure.
#
# El foco del challenge **no es solo que el test pase**, sino que también esté bien estructurado, sea legible y genere reportes claros.
#
#
# **Implementación:**
#
# 1. Abrir el navegador.
# 2. Navegar a `https://automationexercise.com/`
# 3. Validar que la página cargó correctamente.
#   *(por ejemplo: presencia del logo o del texto “Automation Exercise”)*
#
# 4. Ir a la sección **Products**.
# 5. Validar que el catálogo de productos esté visible.
# 6. Validar que haya **al menos un producto** listado.
# 7. Seleccionar **un producto cualquiera**.
# 8. Agregarlo al carrito.
# 9. Validar que se muestre un mensaje o pop-up de confirmación.
# 10. Ir al carrito y validar que:
#    - no esté vacío.
#    - contenga el producto agregado.
#    - Validar el **nombre del producto agregado**.
#    *No es obligatorio validar precios ni finalizar el checkout.*
#
# 11. El test debe finalizar de forma controlada.
# 12. El navegador debe cerrarse correctamente, incluso si ocurre un error.
#
# **Requisitos:**
# - Usar Pytest como framework de test.
# - El test debe tener un nombre descriptivo
# - Usar al menos un marcador.
# - Usar Selenium WebDriver
# - Usar esperas explícitas (WebDriverWait)
# - El reporte de Allure debe incluir:
#   - Nombre del test
#   - Al menos 3 steps de Allure
#   - Al menos 1 screenshot adjuntado al reporte.
# </div>

# %%
# Challenge Integrador 2
# Escribe tu código aquí.
# Dado que es un ejercicio largo, te recomiendo que lo hagas en un archivo nuevo .py
