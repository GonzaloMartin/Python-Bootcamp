# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzaloMartin/Python-Bootcamp/blob/main/Unidad_07/Python_Bootcamp_Clase_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/GonzaloMartin/Python-Bootcamp/refs/heads/main/Assets/python_bootcamp_banner1.png" width="400">
#
# # **Python Bootcamp orientado a la Automatización**
#
# La idea de esta unidad explicar de forma sencilla y práctica los conceptos básicos de programación orientada a objetos (POO) en Python. La POO es un paradigma de programación que utiliza "objetos" para representar datos y funcionalidades, facilitando la organización y reutilización del código.

# %% [markdown]
# # Unidad 7
#
# El objetivo de esta unidad es mostrar los conceptos de Programación Orientada a Objetos y cómo aplicarlos en Python. Esta será un unidad importante de cara a la automatización de tareas, ya que muchos módulos y librerías de Python están basados en POO.
#
# * Programación Orientada a Objetos (POO)
# * Objetos y Clases
# * Constructores y Atributos
# * Métodos
# * Abstracción
# * Encapsulamiento
# * Herencia
# * Polimorfismo
# * Operadores especiales
# * Buenas Prácticas de POO
#
# La clase incluye teoría y práctica sobre cada tema.

# %% [markdown]
# ***
# ## Programación Orientada a Objetos (POO) 🐍
#
# WIP
